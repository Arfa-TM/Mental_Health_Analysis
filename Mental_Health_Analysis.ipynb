# %% [raw]
# import pandas as pd
# import matplotlib.pyplot as plt
# import seaborn as sns
#
# # Load dataset
# df = pd.read_csv("student_depression_dataset.csv")

# %%
df.head()
# Out:
#    id  Gender   Age           City Profession  Academic Pressure  \
# 0   2    Male  33.0  Visakhapatnam    Student                5.0
# 1   8  Female  24.0      Bangalore    Student                2.0
# 2  26    Male  31.0       Srinagar    Student                3.0
# 3  30  Female  28.0       Varanasi    Student                3.0
# 4  32  Female  25.0         Jaipur    Student                4.0
#
#    Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 0            0.0  8.97                 2.0               0.0
# 1            0.0  5.90                 5.0               0.0
# 2            0.0  7.03                 5.0               0.0
# 3            0.0  5.59                 2.0               0.0
# 4            0.0  8.13                 3.0               0.0
#
#         Sleep Duration Dietary Habits   Degree  \
# 0          '5-6 hours'        Healthy  B.Pharm
# 1          '5-6 hours'       Moderate      BSc
# 2  'Less than 5 hours'        Healthy       BA
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27901 entries, 0 to 27900
# Data columns (total 18 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     27901 non-null  int64
#  1   Gender                                 27901 non-null  object
#  2   Age                                    27901 non-null  float64
#  3   City                                   27901 non-null  object
#  4   Profession                             27901 non-null  object
#  5   Academic Pressure                      27901 non-null  float64
#  6   Work Pressure                          27901 non-null  float64
#  7   CGPA                                   27901 non-null  float64
#  8   Study Satisfaction                     27901 non-null  float64
#  9   Job Satisfaction                       27901 non-null  float64
# ...

# %%
df.rename(columns={'Have you ever had suicidal thoughts ?': 'Suicidal Thoughts'}, inplace=True)

# %%
df.isnull().sum()
# Out:
# id                                  0
# Gender                              0
# Age                                 0
# City                                0
# Profession                          0
# Academic Pressure                   0
# Work Pressure                       0
# CGPA                                0
# Study Satisfaction                  0
# Job Satisfaction                    0
# Sleep Duration                      0
# Dietary Habits                      0
# Degree                              0
# Suicidal Thoughts                   0
# Work/Study Hours                    0
# Financial Stress                    0
# Family History of Mental Illness    0
# Depression                          0
# dtype: int64

# %%
df.describe()
# Out:
#                   id           Age  Academic Pressure  Work Pressure  \
# count   27901.000000  27901.000000       27901.000000   27901.000000
# mean    70442.149421     25.822300           3.141214       0.000430
# std     40641.175216      4.905687           1.381465       0.043992
# min         2.000000     18.000000           0.000000       0.000000
# 25%     35039.000000     21.000000           2.000000       0.000000
# 50%     70684.000000     25.000000           3.000000       0.000000
# 75%    105818.000000     30.000000           4.000000       0.000000
# max    140699.000000     59.000000           5.000000       5.000000
#
#                CGPA  Study Satisfaction  Job Satisfaction  Work/Study Hours  \
# count  27901.000000        27901.000000      27901.000000      27901.000000
# mean       7.656104            2.943837          0.000681          7.156984
# std        1.470707            1.361148          0.044394          3.707642
# ...

# %%
df['Depression'].value_counts()
# Out:
# Depression
# 1    16336
# 0    11565
# Name: count, dtype: int64

# %%
df['Depression'] = df['Depression'].replace({1: 'Yes', 0: 'No'})

# %%
sns.countplot(data=df, x='Gender', hue='Depression')
plt.title("Depressin Distribution by Gender")
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

sns.boxplot(data=df, x='Depression', y='Academic Pressure', ax=axes[0])
axes[0].set_title("Academic Pressure vs Depression")

sns.boxplot(data=df, x='Depression', y='Work Pressure', ax=axes[1])
axes[1].set_title("Work Pressure vs Depression")

plt.tight_layout()
plt.show()

# %%
sns.violinplot(data=df, x='Depression', y='Sleep Duration')
plt.title("Sleep Duration by Depression Status")
plt.show()

# %%
pd.crosstab(df['Sleep Duration'], df['Depression'], normalize='index') * 100
# Out:
# Depression                  No        Yes
# Sleep Duration
# '5-6 hours'          43.118227  56.881773
# '7-8 hours'          40.498230  59.501770
# 'Less than 5 hours'  35.487365  64.512635
# 'More than 8 hours'  49.073461  50.926539
# Others               50.000000  50.000000

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

sns.countplot(data=df, x='Financial Stress', hue='Depression', ax=axes[0])
axes[0].set_title("Financial Stress vs Depression")

sns.countplot(data=df, x='Family History of Mental Illness', hue='Depression', ax=axes[1])
axes[1].set_title("Family History vs Depression")

plt.tight_layout()
plt.show()

# %%
sns.scatterplot(data=df, x='CGPA', y='Study Satisfaction', hue='Depression')
plt.title("CGPA vs Study Satisfaction (Colored by Depression)")
plt.show()

# %%
sns.countplot(data=df, x='Suicidal Thoughts', hue='Depression')
plt.title("Suicidal Thoughts vs Depression")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Conclusion:
#
# The analysis reveals that depression is strongly associated with several factors including suicidal thoughts,
# high academic and work pressure, financial stress, and a family history of mental illness.
# Individuals with depression often experience abnormal sleep patterns and are found across all academic performance levels,
# indicating that good grades do not shield against mental health struggles.
# While depression affects both genders, a slightly higher prevalence is observed among males in this dataset.
# These findings highlight the multifaceted nature of depression and underscore the importance of holistic mental health support systems,
# especially in academic and high-pressure environments.
